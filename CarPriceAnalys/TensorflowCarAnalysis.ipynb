# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("merc.xlsx")

# %%
dataFrame
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 0      2005   5200    Automatic    63000  325  32.1         1.8
# 1      2017  34948    Automatic    27000   20  61.4         2.1
# 2      2016  49948    Automatic     6200  555  28.0         5.5
# 3      2016  61948    Automatic    16000  325  30.4         4.0
# 4      2016  73948    Automatic     4000  325  30.1         4.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 13114  2020  35999    Automatic      500  145  55.4         2.0
# 13115  2020  24699    Automatic     2500  145  55.4         2.0
# 13116  2019  30999    Automatic    11612  145  41.5         2.1
# 13117  2019  37990    Automatic     2426  145  45.6         2.0
# 13118  2019  54999    Automatic     2075  145  52.3         2.9
#
# [13119 rows x 7 columns]

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  13119.000000   13119.000000   13119.000000  13119.000000  13119.000000
# mean    2017.296288   24698.596920   21949.559037    129.972178     55.155843
# std        2.224709   11842.675542   21176.512267     65.260286     15.220082
# min     1970.000000     650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000   17450.000000    6097.500000    125.000000     45.600000
# 50%     2018.000000   22480.000000   15189.000000    145.000000     56.500000
# 75%     2019.000000   28980.000000   31779.500000    145.000000     64.200000
# max     2020.000000  159999.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  13119.000000
# mean       2.071530
# std        0.572426
# min        0.000000
# 25%        1.800000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.isnull().sum()#checks whether there is any null point our data
# Out:
# year            0
# price           0
# transmission    0
# mileage         0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize = (7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\4242o\AppData\Local\Temp\ipykernel_19288\3198832459.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sbn.distplot(dataFrame["price"])
# <AxesSubplot: xlabel='price', ylabel='Density'>

# %%
sbn.countplot(dataFrame["year"])
# Out:
# <AxesSubplot: ylabel='count'>

# %%
dataFrame.corr()
# Out:
# C:\Users\4242o\AppData\Local\Temp\ipykernel_19288\3497904997.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.520712 -0.738027  0.012480 -0.094626   -0.142147
# price       0.520712  1.000000 -0.537214  0.268717 -0.438445    0.516126
# mileage    -0.738027 -0.537214  1.000000 -0.160223  0.202850    0.063652
# tax         0.012480  0.268717 -0.160223  1.000000 -0.513742    0.338341
# mpg        -0.094626 -0.438445  0.202850 -0.513742  1.000000   -0.339862
# engineSize -0.142147  0.516126  0.063652  0.338341 -0.339862    1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# C:\Users\4242o\AppData\Local\Temp\ipykernel_19288\625300545.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataFrame.corr()["price"].sort_values()
# mileage      -0.537214
# mpg          -0.438445
# tax           0.268717
# engineSize    0.516126
# year          0.520712
# price         1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot: xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price", ascending= False).head(20) # ascending means values smaller to bigger
# Out:
#        year   price transmission  mileage  tax   mpg  engineSize
# 6199   2020  159999    Semi-Auto     1350  145  21.4         4.0
# 10044  2020  154998    Automatic     3000  150  21.4         4.0
# 5      2011  149948    Automatic     3000  570  21.4         6.2
# 8737   2019  140319    Semi-Auto      785  150  22.1         4.0
# 6386   2018  139995    Semi-Auto    13046  145  21.4         4.0
# 8      2019  139948    Automatic    12000  145  21.4         4.0
# 9133   2019  139559    Semi-Auto     1000  145  22.1         4.0
# 8821   2020  138439    Semi-Auto     1000  145  22.1         4.0
# 5902   2018  135771    Semi-Auto    19000  145  21.4         4.0
# 7864   2018  135124    Semi-Auto    18234  150  21.4         4.0
# 8673   2019  134219    Semi-Auto     1000  145  24.8         4.0
# 6210   2019  129990    Automatic     1000  145  24.8         4.0
# 4759   2019  126000    Automatic      250  145  24.6         4.0
# ...

# %%
dataFrame.sort_values("price", ascending= True).head(20) # ascending means values smaller to bigger
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 11816  2003    650       Manual   109090  235  40.0         1.4
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11174  2001   1695    Automatic   108800  325  31.7         3.2
# 12710  2006   1695    Automatic   153000  300  33.6         1.8
# 12766  2004   1780    Automatic   118000  265  41.5         2.2
# 12009  2007   1800    Automatic    84000  200  42.8         1.5
# 11764  1998   1990    Automatic    99300  265  32.1         2.3
# 11808  1998   1990    Automatic   113557  265  32.1         2.3
# 11383  2005   1995    Automatic   105000  260  43.5         2.1
# 11378  2004   1995    Semi-Auto   165000  330  20.0         3.7
# 11857  2002   2140    Automatic    52700  325  31.4         2.0
# ...

# %%
len(dataFrame)# max values in prices not exactly fit the other values so we will remove these values.
# Out:
# 13119

# %%
len(dataFrame)*0.01# so for this we will take only 99% of data and 131 biggest values will be removed
# Out:
# 131.19

# %%
data99= dataFrame.sort_values("price", ascending= False).iloc[131:]

# %%
data99
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12988 rows x 7 columns]

# %%
data99.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12988.000000  12988.000000   12988.000000  12988.000000  12988.000000
# mean    2017.281876  24074.926933   22132.741146    129.689714     55.437142
# std        2.228515   9866.224575   21196.776401     65.183076     15.025999
# min     1970.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17357.500000    6322.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15369.500000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31982.250000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12988.000000
# mean       2.050901
# std        0.532596
# min        0.000000
# 25%        1.675000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame= data99

# %%
dataFrame = dataFrame[dataFrame.year != 1970] # removed 1970 year

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax           mpg  \
# count  12987.000000  12987.000000   12987.000000  12987.000000  12987.000000
# mean    2017.285516  24074.855779   22133.367367    129.676215     55.438392
# std        2.189633   9866.601115   21197.472376     65.167429     15.025902
# min     1997.000000    650.000000       1.000000      0.000000      1.100000
# 25%     2016.000000  17355.000000    6320.000000    125.000000     45.600000
# 50%     2018.000000  22299.000000   15371.000000    145.000000     56.500000
# 75%     2019.000000  28706.000000   31986.500000    145.000000     64.200000
# max     2020.000000  65990.000000  259000.000000    580.000000    217.300000
#
#          engineSize
# count  12987.000000
# mean       2.051059
# std        0.532313
# min        0.000000
# 25%        1.700000
# 50%        2.000000
# 75%        2.100000
# max        6.200000

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# C:\Users\4242o\AppData\Local\Temp\ipykernel_19288\2092793654.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataFrame.groupby("year").mean()["price"]
# year
# 1997     9995.000000
# 1998     8605.000000
# 1999     5995.000000
# 2000     5743.333333
# 2001     4957.900000
# 2002     5820.444444
# 2003     4878.000000
# 2004     4727.615385
# 2005     4426.111111
# 2006     4036.875000
# 2007     5136.045455
# 2008     6967.437500
# 2009     6166.764706
# 2010     8308.473684
# 2011     8913.459459
# 2012    10845.140351
# 2013    11939.842466
# 2014    14042.936864
# 2015    16647.822222
# 2016    19223.558943
# 2017    21356.280421
# 2018    24800.844506
# 2019    30289.524832
# 2020    34234.794872
# Name: price, dtype: float64

# %%
dataFrame # we cannot use transmission because it is nonnumerical data so we will remove it
# Out:
#        year  price transmission  mileage  tax   mpg  engineSize
# 6177   2019  65990    Semi-Auto     5076  150  30.4         3.0
# 5779   2020  65990    Semi-Auto      999  145  28.0         4.0
# 3191   2020  65980    Semi-Auto     3999  145  28.0         4.0
# 4727   2019  65000    Semi-Auto     3398  145  27.2         4.0
# 8814   2019  64999    Semi-Auto      119  145  40.9         3.0
# ...     ...    ...          ...      ...  ...   ...         ...
# 11549  2002   1495    Automatic    13800  305  39.8         2.7
# 12594  2004   1495       Manual   119000  300  34.5         1.8
# 11765  2000   1490    Automatic    87000  265  27.2         3.2
# 12008  2010   1350       Manual   116126  145  54.3         2.0
# 11816  2003    650       Manual   109090  235  40.0         1.4
#
# [12987 rows x 7 columns]

# %%
dataFrame = dataFrame.drop("transmission", axis=1)

# %%
y = dataFrame["price"].values
x = dataFrame.drop("price",axis=1)

# %%
y
# Out:
# array([65990, 65990, 65980, ...,  1490,  1350,   650], dtype=int64)

# %%
x
# Out:
#        year  mileage  tax   mpg  engineSize
# 6177   2019     5076  150  30.4         3.0
# 5779   2020      999  145  28.0         4.0
# 3191   2020     3999  145  28.0         4.0
# 4727   2019     3398  145  27.2         4.0
# 8814   2019      119  145  40.9         3.0
# ...     ...      ...  ...   ...         ...
# 11549  2002    13800  305  39.8         2.7
# 12594  2004   119000  300  34.5         1.8
# 11765  2000    87000  265  27.2         3.2
# 12008  2010   116126  145  54.3         2.0
# 11816  2003   109090  235  40.0         1.4
#
# [12987 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3,random_state=10)#data is splited 2 as train and test in both x an y

# %%
len(x_train)
# Out:
# 9090

# %%
len(x_test)
# Out:
# 3897

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train)#scaling data again
x_test= scaler.transform(x_test)

# %%
x_train.shape
# Out:
# (9090, 5)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(12,activation="relu"))#added new layers with 12 neurons
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))
model.add(Dense(12,activation="relu"))

model.add(Dense(1))#output layer
model.compile(optimizer ="adam",loss="mse")#for compiling according to mse(mean square error)

# %%
model.fit(x=x_train, y=y_train,validation_data=(x_test,y_test),batch_size=250,epochs=300 )
# Out:
# Epoch 1/300
# 37/37 [==============================] - 2s 12ms/step - loss: 672144384.0000 - val_loss: 688102080.0000
# Epoch 2/300
# 37/37 [==============================] - 0s 6ms/step - loss: 672122112.0000 - val_loss: 688062400.0000
# Epoch 3/300
# 37/37 [==============================] - 0s 6ms/step - loss: 672050240.0000 - val_loss: 687939968.0000
# Epoch 4/300
# 37/37 [==============================] - 0s 8ms/step - loss: 671837184.0000 - val_loss: 687579136.0000
# Epoch 5/300
# 37/37 [==============================] - 0s 6ms/step - loss: 671247296.0000 - val_loss: 686640384.0000
# Epoch 6/300
# 37/37 [==============================] - 0s 6ms/step - loss: 669825024.0000 - val_loss: 684512704.0000
# Epoch 7/300
# 37/37 [==============================] - 0s 6ms/step - loss: 666793920.0000 - val_loss: 680202368.0000
# Epoch 8/300
# 37/37 [==============================] - 0s 8ms/step - loss: 660932160.0000 - val_loss: 672158784.0000
# Epoch 9/300
# ...

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.head()
# Out:
#           loss     val_loss
# 0  672144384.0  688102080.0
# 1  672122112.0  688062400.0
# 2  672050240.0  687939968.0
# 3  671837184.0  687579136.0
# 4  671247296.0  686640384.0

# %%
loss.plot()
# Out:
# <AxesSubplot: >

# %%
guess = model.predict(x_test)
# Out:
# 122/122 [==============================] - 0s 2ms/step

# %%
guess
# Out:
# array([[22497.826],
#        [24051.986],
#        [25077.982],
#        ...,
#        [26471.283],
#        [13473.673],
#        [25044.447]], dtype=float32)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(y_test,guess)
# Out:
# 3228.0393120597073

# %%
plt.scatter(y_test,guess)

# %%
dataFrame["price"].iloc[2]# an example is it working?
# Out:
# 65980

# %%
newCar = dataFrame.drop("price",axis=1).iloc[2]

# %%
newCar =scaler.transform(newCar.values.reshape(-1,5))
# Out:
# C:\Users\4242o\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
newCar
# Out:
# array([[1.        , 0.01543635, 0.25      , 0.12442183, 0.64516129]])

# %%
model.predict(newCar)
# Out:
# 1/1 [==============================] - 0s 46ms/step
# array([[62688.1]], dtype=float32)
